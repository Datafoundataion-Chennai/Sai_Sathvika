# %%
# !pip install pytest
# Out:
# Requirement already satisfied: pytest in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (7.4.4)
# Requirement already satisfied: iniconfig in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from pytest) (1.1.1)
# Requirement already satisfied: packaging in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from pytest) (24.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from pytest) (1.0.0)
# Requirement already satisfied: colorama in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from pytest) (0.4.6)

# %%
# !pytest --version
# Out:
# pytest 7.4.4

# %%
# !pytest testcases.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.7, pytest-7.4.4, pluggy-1.0.0
# rootdir: C:\Users\K_V_S_Sathvika
# plugins: anyio-4.2.0
# collected 1 item
#
# testcases.py .                                                           [100%]
#
# ============================== 1 passed in 0.00s ==============================

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\k_v_s_sathvika\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# %matplotlib inline

# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
x=np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y,label="line plot",color="green",linestyle="--")
plt.xlabel("time")
plt.ylabel("speed")
plt.title("DISTANCE")
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
colors=np.random.rand(50)
plt.scatter(x,y,c=colors,edgecolor="black")
plt.colorbar()
plt.show()
print(x,y)
# Out:
# [0.14294307 0.38946504 0.95477747 0.74461221 0.90102813 0.30852981
#  0.36678456 0.36821058 0.11335787 0.43152595 0.45414747 0.21952
#  0.77520553 0.77379093 0.76797369 0.21169531 0.19263954 0.61738639
#  0.81512316 0.7658223  0.31472943 0.4565278  0.33344822 0.11644581
#  0.75792675 0.33862051 0.79721649 0.22665107 0.65136013 0.66331109
#  0.04354624 0.11032869 0.4551821  0.93398431 0.17402538 0.24985622
#  0.27368328 0.07789709 0.33439941 0.50811028 0.33538747 0.23509112
#  0.83009916 0.23737127 0.65956396 0.34197761 0.29970023 0.85227121
#  0.36609194 0.91335833] [0.00391276 0.58171536 0.90212723 0.82497088 0.02208374 0.26556491
#  0.69097044 0.89125518 0.77568393 0.26229678 0.7910643  0.9644543
#  0.66690542 0.79814441 0.56392111 0.42351415 0.90567659 0.80622596
#  0.650301   0.50134823 0.66858033 0.92743614 0.75333603 0.4749029
#  0.68569259 0.66854321 0.94870914 0.65869319 0.84366558 0.52511978
#  0.24037782 0.35778239 0.35964444 0.80452422 0.09510546 0.75988099
#  0.522948   0.80547709 0.66932912 0.36540836 0.04710073 0.19706529
#  0.24202873 0.03829029 0.73970888 0.14365509 0.10106948 0.39130727
#  0.17359852 0.1612086 ]

# %%
cars=["audi","benz","honda"]
prices=[150000.00,450000.00,500000.00]
plt.bar(cars,prices,color=['red','green','blue'])
plt.xlabel("cars")
plt.ylabel("prices")
plt.show()

# %%
labels=["python","java","mysql"]
values=[4,5,6]
colors=["blue","green","red"]
plt.pie(values,labels=labels,colors=colors,startangle=130)
plt.title("programming languages")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
weeks = np.arange(1, 9)  
covid_cases = [500, 700, 1200, 2000, 3000, 4500, 6000, 8000]  
vaccination_rate = [5, 10, 20, 35, 50, 65, 75, 85] 
fig,ax=plt.subplots(2,1,figsize=(10,8))
ax[0].plot(weeks,covid_cases,marker='x',linestyle='-',color='red',label="week_cases")
ax[0].set_xlabel("Weeks")
ax[0].set_ylabel("covid_cases")
ax[0].set_title("weekly COVID-19 cases")
ax[0].legend()
ax[0].grid(True)
ax[1].bar(weeks,vaccination_rate,color='blue',label="vaccination_rate")
ax[1].set_xlabel("Weeks")
ax[1].set_ylabel("vaccination_rate")
ax[1].set_title("vaccination progress (%)")
ax[1].legend()
ax[1].grid(True)
ax[1].grid(axis="y",linestyle="--",alpha=0.7)
plt.tight_layout()
plt.show()

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
rent = [1200, 1200, 1200, 1200, 1250, 1250]
food = [400, 420, 450, 480, 500, 520]
entertainment = [150, 200, 220, 180, 250, 300]
transport = [100, 120, 130, 110, 140, 160]
plt.bar(months,rent,label="rents",color="green")
plt.bar(months,food,label="food",color="blue")
plt.bar(months,entertainment,label="entertainment",color="pink")
plt.bar(months,transport,label="transport",color="yellow")
plt.xlabel("months")
plt.ylabel("Expenses")
plt.title("Monthly Expenses Comparison")
plt.legend()
plt.show()
